# %% [markdown]
# ## Web Scraping Assignment 3

# %% [markdown]
# ### 1. Python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.
#
#
# ### 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
import pandas as pd
import selenium
import requests
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from bs4 import BeautifulSoup

# %%
driver =  webdriver.Chrome("chromedriver.exe")
driver.get("https://www.Amazon.in/")
driver.maximize_window()

# %%
Titles = []
Ratings = []
Prices = []
Rated = []
Delivery = []
Images = []

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")
search_bar.clear()
search_bar.send_keys("guitar")
search_button = driver.find_element_by_xpath('//span[@id="nav-search-submit-text"]')
search_button.click()

# %%
prices1=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in prices1:
    Prices.append(i.text)
titles1=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
for i in titles1:
    Titles.append(i.text)

# %%
Prices
# Out:
# ['6,999',
#  '5,999',
#  '6,499',
#  '599',
#  '2,649',
#  '2,649',
#  '2,290',
#  '7,199',
#  '2,649',
#  '2,649',
#  '2,390',
#  '3,980',
#  '2,390',
#  '3,690',
#  '3,790',
#  '2,399',
#  '5,999',
#  '3,035',
#  '2,190',
#  '2,649',
#  '332',
#  '999',
#  '1,099',
#  '447',
#  '797',
#  '999',
#  '2,590',
#  '3,179',
#  '2,649',
#  '630',
#  '5,499',
#  '599',
#  '2,190',
#  '2,599',
#  '6,999',
#  '497',
#  '2,290',
#  '3,179',
#  '949',
#  '2,649',
#  '4,399',
#  '786',
#  '3,599',
#  '499',
#  '3,329',
#  '2,649',
#  '6,349',
#  '5,999',
#  '2,649',
#  '5,499',
#  '4,009',
#  '7,047',
#  '3,690',
#  '9,749',
#  '399',
#  '175',
#  '589',
#  '499',
#  '399']

# %%
Titles
# Out:
# ['Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (black & stand)',
#  'Kadence Frontier Series, Natural Acoustic Guitar With Die Cast Keys Super Combo(Tuner,Capo,Bag,strap,strings and 3 picks)',
#  'GUITAR BRO - COMBO (Black Acoustic Guitar for Beginner, Guitar Learning Kit, Song Book, Video Lectures, Accessories like Pick, Bag)',
#  'Laxmi Musical Electronics - Acoustic Pickup for Violin,Veena,Guitar,Mandalin, Banjo and All Acoustic String Instruments',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway with Bag (TBS Transparent Blue Sunburst)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 Inch Cutaway, Right Handed, White with Bag, Strings, Picks and Strap',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar (Sunburst, 6 Strings)',
#  'Intern INT-38C Acoustic Guitar Kit (Sunburst) with Carry bag, Picks, Strings set and Guitar Strap, Small',
#  'Hovner 215 Black F-Cut Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks By K-Retail',
#  'Intern INT-38C-BK-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Black, 6 Strings)',
#  'Kordz Luana Natural Wooden 41 Inch Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks',
#  'Giuson Venus Black 41 Inch Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks by K-Retail',
#  'Medellin MED-BLU-C Linden Wood Acoustic Guitar',
#  'Kadence Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set of Strings, Strap, Picks and Bag (Black EQ, Electric Acoustic)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Blue',
#  'Intern INT-38C Natural Acoustic Guitar kit with carry bag & picks',
#  'JUAREZ Acoustic Guitar, [LEFT HANDED] 38 Inch Cutaway, 38CL/TBLS with Bag, Strings, Pick and Strap, Blue Sunburst',
#  'Guitar Tuner Tuner Guitar Tuner Clip On for Guitar Ukulele Violin Viola Bass Chromatic Tuning Modes 360 Degree Rotating Fast & Accurate',
#  'Honestum 4-string acoustic guitar learning kids toy, brown 18-Multi color',
#  'HRB MUSICALS® 50 Pcs Guitar String Tool Kit Including 3 Guitar Strings SET, 1 Guitar Tuner, 15 Picks, 1 black Capo with Pins remover, 1 pick holder, 12 Guitar pins, 1 guitar Cutter and 1 Winder',
#  'DEVICE OF URBAN INFOTECH 360 degree Rotational Electronic Highly Accurate Clip-on Digital Tuner Easy to Use for Acoustic and Electric Guitar Bass Violin Ukulele with Picks(Design May Vary)',
#  'DEVICE OF URBAN INFOTECH Guitar Tuner 360 degree Digital Tuner Easy to Use Highly Accurate Clip-on Tuner Best for Acoustic and Electric Guitar Bass Violin Ukulele With Capo & 5 Picks(Design may very)',
#  'SAAN Life Science 4-string Small Acoustic Guitar Musical Instrument Educational Learning kids Toy for Beginners - 23Inch',
#  'Intern INT-38C-SB-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Sunburst, 6 Strings)',
#  'JUAREZ JRZ38CTR/BK 38 Inch Acoustic Guitar with Dual Action Truss Rod, Bag, Picks, Allen Key, Extra String Set, Black',
#  'JUAREZ Acoustic Guitar, [LEFT HANDED] 38 Inch Cutaway, 38CL/3TS with Bag, Strings, Pick and Strap, 3TS Sunburst (JRZ38CL/3TS)',
#  "D'Addario EZ900 Acoustic Guitar Strings, Pack of 2",
#  'Kadence Frontier Series, Acoustic Guitar With/Wihtout EQ Die Cast Keys Combo (Bag,strap,strings and 3 picks) (Brown, Acoustic)',
#  'Guitar Accessories Set 9 Pieces Guitar Tool Kit Including Guitar Capo Tuner String Winder Guitar Picks Guitar Bones Pick Holder for acoustic electric guitar player',
#  'Intern INT-38C Brown Acoustic Guitar kit with carry bag & picks',
#  'Jixing Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'DIKUJI ENTERPRISE Classical Series Guitar Musical Instrument for Beginners Kids(Small)',
#  'YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (black & stand)',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L (6PCS)',
#  'Juârez JRZ38C/MAH 6 Strings Acoustic Guitar 38 Inch Cutaway, Right Handed, Mahogany with Bag, Strings, Picks and Strap',
#  'JUAREZ 38 Inch Acoustic Guitar with Dual Action Truss Rod, Bag, Picks, Allen Key, Extra String Set, 3TS Sunburst',
#  "hd fashion 4 String Decor Guitar Children's Musical Instrument Educational Toy Small Guitar for Beginners Kids Child (multicolor)",
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38C with Bag, Strings, Pick and Strap, Blue',
#  'GIVSON Ketostics Venus Special Guitar (black) with bag, string set, belt and 5 picks',
#  'SUNRISE (4 STRING SMALL GUITAR) 4-String 16" Guitar Musical Instrument Educational for Children\'s Toy Acoustic & Classic Guitar That Look Stylish Instruments Beginner Musical Sound Toys Best Gift for Kids (Multicolor)',
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar-Natural',
#  'TECHBLAZE Acoustic Guitar Strings, Guitar Wall Mount, Guitar Metal Capo with 5 picks Best Guitar Accessory Combo Pack',
#  'JUAREZ 41 INCH GUITAR JRZ41VG/BK, BLACK',
#  'Juarez Acoustic Guitar, [ LEFT HANDED] 38 Inch Cutaway, 38CL/BK with Bag, Strings, Pick and Strap, Black',
#  'Martin Smith W-101-N-PK Acoustic Guitar Super Kit with Stand (Natural)',
#  'Kadence Frontier Series, Natural Acoustic Guitar With Die Cast Keys Super Combo(Tuner,Capo,Bag,strap,strings and 3 picks)',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway with Pick Guard, 38C/RDS with Bag, Strings, Pick and Strap, Red Sunburst',
#  'GIVSON"CAMBRIDGE" 6-STRING ELECTRO-ACOUSTIC GUITAR WITH GUITAR BAG, WALL MOUNT, CAPO, STRING SET AND PICKS (RED)',
#  'JUAREZ Fiésta 41 Inch Acoustic Guitar with Dual Action Truss Rod, 21 Frets Rosewood Fretboard & Bridge, Padded 5mm Cotton Bag, Cotton Strap, 2 Picks, Allen Key, Extra String Set, Brown',
#  'Ibanez MD39C-NT Acoustic Guitar (Natural)',
#  'Kordz Luana Black Matt Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks V2',
#  'Yamaha FS100C Acoustic Guitar, Natural',
#  'Perlman Guitar Fretboard, Fingerboard Stickers, Decals Tool for Learner Or Beginner',
#  'Siko E1st, B2nd And G3rd Acoustic Guitar Strings',
#  'HRB MUSICALS combo guitar stand & guitar bag NON PADDED',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L(6 PCS)',
#  'HRB MUSICALS combo of guitar String Winder, guitar Capo (black), 5-Piece/Plectrum of Alice Guitar-String set']

# %%
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
url1=[]
for i in urls:
    url1.append(i.get_attribute('href'))
for url in url1:
    driver.get(url)
    try:
        deliveries=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']")
        Delivery.append(deliveries.text)
        rate=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        rates=driver.find_element_by_xpath("//span[@class='a-size-base a-color-secondary']")
        Rated.append(rates.text)
    except NoSuchElementException as e:
        Ratings.append("No rating")
        Rated.append("No rating")
        Delivery.append("No rating")

# %%
url="https://www.amazon.in/s?k=guitar&ref=nb_sb_noss"
driver.get(url)
urls=driver.find_elements_by_xpath("//img[@class='s-image']")
for i in urls:
    Images.append(i.get_attribute('src'))
for url in Images:
    driver.get(url)

# %%
Ratings
# Out:
# ['3.9 out of 5',
#  '3.8 out of 5',
#  '3.7 out of 5',
#  '3.5 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '3.8 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.8 out of 5',
#  'No rating',
#  '4.3 out of 5',
#  'No rating',
#  '4.2 out of 5',
#  '3.7 out of 5',
#  '2.3 out of 5',
#  '3.6 out of 5',
#  '4 out of 5',
#  '3.8 out of 5',
#  '5 out of 5',
#  '4.4 out of 5',
#  '4 out of 5',
#  '3.6 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '1 out of 5',
#  '4.1 out of 5',
#  '3.9 out of 5',
#  '4.5 out of 5',
#  '3.6 out of 5',
#  '3.6 out of 5',
#  '5 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  'No rating',
#  '3.9 out of 5',
#  'No rating',
#  '3.2 out of 5',
#  '3.9 out of 5',
#  '4.3 out of 5',
#  '3.8 out of 5',
#  '3.9 out of 5',
#  'No rating',
#  '3.8 out of 5',
#  '4.4 out of 5',
#  '5 out of 5',
#  '4.4 out of 5',
#  '4.5 out of 5',
#  '3.7 out of 5',
#  '3.3 out of 5',
#  '3.2 out of 5',
#  '3.7 out of 5']

# %%
Rated
# Out:
# ['984 global ratings',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'No rating',
#  'Total price:',
#  'No rating',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  '2 global ratings',
#  '72 global ratings',
#  '984 global ratings',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'No rating',
#  'Total price:',
#  'No rating',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'No rating',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  '175 global ratings',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:']

# %%
Delivery
# Out:
# ['FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Aug 28 - Sep 1 Details\nFastest delivery: Aug 27 - 31 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Saturday, Aug 28 Details',
#  'FREE delivery: Friday, Sep 3 Details',
#  'FREE delivery: Wednesday, Aug 25 Details\nFastest delivery: Tomorrow\nOrder within 3 hrs and 34 mins Details',
#  'FREE delivery: Wednesday, Aug 25 Details\nFastest delivery: Tomorrow\nOrder within 3 hrs and 34 mins Details',
#  'No rating',
#  'FREE delivery: Monday, Aug 30 Details',
#  'FREE delivery: Saturday, Aug 28 Details',
#  'No rating',
#  'FREE delivery: Sunday, Aug 29 Details',
#  'FREE delivery: Tuesday, Aug 31 on orders over ₹499.00 shipped by Amazon Details',
#  'FREE delivery: Tuesday, Aug 31 Details',
#  'FREE delivery: Saturday, Aug 28 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Monday, Aug 30 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Monday, Aug 30 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  '',
#  '',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Tuesday, Aug 31 on orders over ₹499.00 shipped by Amazon Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Wednesday, Aug 25 Details\nFastest delivery: Tomorrow\nOrder within 3 hrs and 32 mins Details',
#  'FREE delivery: Aug 28 - 29 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  '',
#  'FREE delivery: Saturday, Aug 28 Details',
#  'No rating',
#  'FREE delivery: Saturday, Aug 28 Details',
#  'FREE delivery: Monday, Aug 30 Details',
#  'No rating',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  '₹99.00 delivery: Aug 28 - 31 Details',
#  'No rating',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Saturday, Aug 28 Details',
#  'FREE delivery: Friday, Aug 27 Details',
#  'FREE delivery: Thursday, Aug 26 Details',
#  '₹100.00 delivery: Aug 30 - 31 Details',
#  'FREE delivery: Sunday, Aug 29 Details',
#  'FREE delivery: Sunday, Aug 29 Details',
#  'FREE delivery: Tuesday, Aug 31 Details',
#  'FREE delivery: Sunday, Aug 29 Details']

# %%
print(len(Titles))
print(len(Prices))
print(len(Ratings))
print(len(Delivery))
print(len(Rated))
print(len(Images))
# Out:
# 60
# 59
# 61
# 66
# 61
# 60

# %%
import pandas as pd
amazon=pd.DataFrame({})
amazon['Titles']=Titles[0:58]
amazon['Prices']=Prices[0:58]
amazon['Ratings']=Ratings[0:58]
amazon['Rates']=Rated[0:58]
amazon['Delivery']=Delivery[0:58]
amazon['Images']=Images[0:58]

# %%
amazon
# Out:
#                                                Titles Prices       Ratings  \
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...  6,999  3.9 out of 5
# 1   Kadence Frontier Series, Natural Acoustic Guit...  5,999  3.8 out of 5
# 2   GUITAR BRO - COMBO (Black Acoustic Guitar for ...  6,499  3.7 out of 5
# 3   Laxmi Musical Electronics - Acoustic Pickup fo...    599  3.5 out of 5
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  2,649  3.9 out of 5
# 5   Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway...  2,649    4 out of 5
# 6   Intern INT-38C Acoustic Guitar Kit, With Bag, ...  2,290  3.9 out of 5
# 7   Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 ...  7,199  3.9 out of 5
# 8   JUAREZ JRZ38C Right Handed Acoustic Guitar (Su...  2,649  3.9 out of 5
# 9   Intern INT-38C Acoustic Guitar Kit (Sunburst) ...  2,649    4 out of 5
# 10  Hovner 215 Black F-Cut Rosewood Fretboard Acou...  2,390  3.9 out of 5
# 11  Intern INT-38C-BK-G Cutaway Right Handed Acous...  3,980    4 out of 5
# 12  Kordz Luana Natural Wooden 41 Inch Rosewood Fr...  2,390    4 out of 5
# 13  Giuson Venus Black 41 Inch Rosewood Fretboard ...  3,690  3.8 out of 5
# 14     Medellin MED-BLU-C Linden Wood Acoustic Guitar  3,790  3.9 out of 5
# 15  Kadence Guitar Frontier Series, Electric Acous...  2,399  3.9 out of 5
# 16  Intern INT-38C Acoustic Guitar Kit, With Bag, ...  5,999    4 out of 5
# 17  Intern INT-38C Natural Acoustic Guitar kit wit...  3,035  3.9 out of 5
# 18  JUAREZ Acoustic Guitar, [LEFT HANDED] 38 Inch ...  2,190  3.8 out of 5
# 19  Guitar Tuner Tuner Guitar Tuner Clip On for Gu...  2,649     No rating
# 20  Honestum 4-string acoustic guitar learning kid...    332  4.3 out of 5
# 21  HRB MUSICALS® 50 Pcs Guitar String Tool Kit In...    999     No rating
# 22  DEVICE OF URBAN INFOTECH 360 degree Rotational...  1,099  4.2 out of 5
# 23  DEVICE OF URBAN INFOTECH Guitar Tuner 360 degr...    447  3.7 out of 5
# 24  SAAN Life Science 4-string Small Acoustic Guit...    797  2.3 out of 5
# 25  Intern INT-38C-SB-G Cutaway Right Handed Acous...    999  3.6 out of 5
# 26  JUAREZ JRZ38CTR/BK 38 Inch Acoustic Guitar wit...  2,590    4 out of 5
# 27  JUAREZ Acoustic Guitar, [LEFT HANDED] 38 Inch ...  3,179  3.8 out of 5
# 28  D'Addario EZ900 Acoustic Guitar Strings, Pack ...  2,649    5 out of 5
# 29  Kadence Frontier Series, Acoustic Guitar With/...    630  4.4 out of 5
# 30  Guitar Accessories Set 9 Pieces Guitar Tool Ki...  5,499    4 out of 5
h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
for i in titles:
    Titles.append(i.text)

# %%
Prices
# Out:
# ['6,999',
#  '5,999',
#  '6,499',
#  '599',
#  '2,649',
#  '2,649',
#  '2,290',
#  '7,199',
#  '2,649',
#  '2,649',
#  '2,390',
#  '3,980',
#  '2,390',
#  '3,690',
#  '3,790',
#  '2,399',
#  '5,999',
#  '3,035',
#  '2,190',
#  '2,649',
#  '332',
#  '999',
#  '1,099',
#  '447',
#  '797',
#  '999',
#  '2,590',
#  '3,179',
#  '2,649',
#  '630',
#  '5,499',
#  '599',
#  '2,190',
#  '2,599',
#  '6,999',
#  '497',
#  '2,290',
#  '3,179',
#  '949',
#  '2,649',
#  '4,399',
#  '786',
#  '3,599',
#  '499',
#  '3,329',
#  '2,649',
#  '6,349',
#  '5,999',
#  '2,649',
#  '5,499',
#  '4,009',
#  '7,047',
#  '3,690',
#  '9,749',
#  '399',
#  '175',
#  '589',
#  '499',
#  '399',
#  '6,499',
#  '749',
#  '497',
#  '399',
#  '5,499',
#  '899',
#  '2,856',
#  '7,199',
#  '4,599',
#  '5,499',
#  '5,999',
#  '899',
#  '5,979',
#  '6,999',
#  '189',
#  '5,499',
#  '4,009',
#  '999',
#  '5,499',
#  '899',
#  '619',
#  '6,999',
#  '329',
#  '2,795',
#  '450',
#  '6,509',
#  '449',
#  '3,999',
#  '399',
#  '999',
#  '4,789',
#  '998',
#  '13,999',
#  '8,999',
#  '6,349',
#  '11,999',
#  '349',
#  '195',
#  '949',
#  '4,455',
#  '4,999',
#  '388',
#  '9,739',
#  '1,399',
#  '3,540',
#  '2,344',
#  '1,748',
#  '5,759',
#  '799',
#  '7,199']

# %%
Titles
# Out:
# ['Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (black & stand)',
#  'Kadence Frontier Series, Natural Acoustic Guitar With Die Cast Keys Super Combo(Tuner,Capo,Bag,strap,strings and 3 picks)',
#  'GUITAR BRO - COMBO (Black Acoustic Guitar for Beginner, Guitar Learning Kit, Song Book, Video Lectures, Accessories like Pick, Bag)',
#  'Laxmi Musical Electronics - Acoustic Pickup for Violin,Veena,Guitar,Mandalin, Banjo and All Acoustic String Instruments',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway with Bag (TBS Transparent Blue Sunburst)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 Inch Cutaway, Right Handed, White with Bag, Strings, Picks and Strap',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar (Sunburst, 6 Strings)',
#  'Intern INT-38C Acoustic Guitar Kit (Sunburst) with Carry bag, Picks, Strings set and Guitar Strap, Small',
#  'Hovner 215 Black F-Cut Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks By K-Retail',
#  'Intern INT-38C-BK-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Black, 6 Strings)',
#  'Kordz Luana Natural Wooden 41 Inch Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks',
#  'Giuson Venus Black 41 Inch Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks by K-Retail',
#  'Medellin MED-BLU-C Linden Wood Acoustic Guitar',
#  'Kadence Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set of Strings, Strap, Picks and Bag (Black EQ, Electric Acoustic)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Blue',
#  'Intern INT-38C Natural Acoustic Guitar kit with carry bag & picks',
#  'JUAREZ Acoustic Guitar, [LEFT HANDED] 38 Inch Cutaway, 38CL/TBLS with Bag, Strings, Pick and Strap, Blue Sunburst',
#  'Guitar Tuner Tuner Guitar Tuner Clip On for Guitar Ukulele Violin Viola Bass Chromatic Tuning Modes 360 Degree Rotating Fast & Accurate',
#  'Honestum 4-string acoustic guitar learning kids toy, brown 18-Multi color',
#  'HRB MUSICALS® 50 Pcs Guitar String Tool Kit Including 3 Guitar Strings SET, 1 Guitar Tuner, 15 Picks, 1 black Capo with Pins remover, 1 pick holder, 12 Guitar pins, 1 guitar Cutter and 1 Winder',
#  'DEVICE OF URBAN INFOTECH 360 degree Rotational Electronic Highly Accurate Clip-on Digital Tuner Easy to Use for Acoustic and Electric Guitar Bass Violin Ukulele with Picks(Design May Vary)',
#  'DEVICE OF URBAN INFOTECH Guitar Tuner 360 degree Digital Tuner Easy to Use Highly Accurate Clip-on Tuner Best for Acoustic and Electric Guitar Bass Violin Ukulele With Capo & 5 Picks(Design may very)',
#  'SAAN Life Science 4-string Small Acoustic Guitar Musical Instrument Educational Learning kids Toy for Beginners - 23Inch',
#  'Intern INT-38C-SB-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Sunburst, 6 Strings)',
#  'JUAREZ JRZ38CTR/BK 38 Inch Acoustic Guitar with Dual Action Truss Rod, Bag, Picks, Allen Key, Extra String Set, Black',
#  'JUAREZ Acoustic Guitar, [LEFT HANDED] 38 Inch Cutaway, 38CL/3TS with Bag, Strings, Pick and Strap, 3TS Sunburst (JRZ38CL/3TS)',
#  "D'Addario EZ900 Acoustic Guitar Strings, Pack of 2",
#  'Kadence Frontier Series, Acoustic Guitar With/Wihtout EQ Die Cast Keys Combo (Bag,strap,strings and 3 picks) (Brown, Acoustic)',
#  'Guitar Accessories Set 9 Pieces Guitar Tool Kit Including Guitar Capo Tuner String Winder Guitar Picks Guitar Bones Pick Holder for acoustic electric guitar player',
#  'Intern INT-38C Brown Acoustic Guitar kit with carry bag & picks',
#  'Jixing Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'DIKUJI ENTERPRISE Classical Series Guitar Musical Instrument for Beginners Kids(Small)',
#  'YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (black & stand)',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L (6PCS)',
#  'Juârez JRZ38C/MAH 6 Strings Acoustic Guitar 38 Inch Cutaway, Right Handed, Mahogany with Bag, Strings, Picks and Strap',
#  'JUAREZ 38 Inch Acoustic Guitar with Dual Action Truss Rod, Bag, Picks, Allen Key, Extra String Set, 3TS Sunburst',
#  "hd fashion 4 String Decor Guitar Children's Musical Instrument Educational Toy Small Guitar for Beginners Kids Child (multicolor)",
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38C with Bag, Strings, Pick and Strap, Blue',
#  'GIVSON Ketostics Venus Special Guitar (black) with bag, string set, belt and 5 picks',
#  'SUNRISE (4 STRING SMALL GUITAR) 4-String 16" Guitar Musical Instrument Educational for Children\'s Toy Acoustic & Classic Guitar That Look Stylish Instruments Beginner Musical Sound Toys Best Gift for Kids (Multicolor)',
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar-Natural',
#  'TECHBLAZE Acoustic Guitar Strings, Guitar Wall Mount, Guitar Metal Capo with 5 picks Best Guitar Accessory Combo Pack',
#  'JUAREZ 41 INCH GUITAR JRZ41VG/BK, BLACK',
#  'Juarez Acoustic Guitar, [ LEFT HANDED] 38 Inch Cutaway, 38CL/BK with Bag, Strings, Pick and Strap, Black',
#  'Martin Smith W-101-N-PK Acoustic Guitar Super Kit with Stand (Natural)',
#  'Kadence Frontier Series, Natural Acoustic Guitar With Die Cast Keys Super Combo(Tuner,Capo,Bag,strap,strings and 3 picks)',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway with Pick Guard, 38C/RDS with Bag, Strings, Pick and Strap, Red Sunburst',
#  'GIVSON"CAMBRIDGE" 6-STRING ELECTRO-ACOUSTIC GUITAR WITH GUITAR BAG, WALL MOUNT, CAPO, STRING SET AND PICKS (RED)',
#  'JUAREZ Fiésta 41 Inch Acoustic Guitar with Dual Action Truss Rod, 21 Frets Rosewood Fretboard & Bridge, Padded 5mm Cotton Bag, Cotton Strap, 2 Picks, Allen Key, Extra String Set, Brown',
#  'Ibanez MD39C-NT Acoustic Guitar (Natural)',
#  'Kordz Luana Black Matt Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks V2',
#  'Yamaha FS100C Acoustic Guitar, Natural',
#  'Perlman Guitar Fretboard, Fingerboard Stickers, Decals Tool for Learner Or Beginner',
#  'Siko E1st, B2nd And G3rd Acoustic Guitar Strings',
#  'HRB MUSICALS combo guitar stand & guitar bag NON PADDED',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L(6 PCS)',
#  'HRB MUSICALS combo of guitar String Winder, guitar Capo (black), 5-Piece/Plectrum of Alice Guitar-String set',
#  'GUITAR BRO - COMBO (Blue Acoustic Guitar for Beginner, Guitar Learning Kit, Song Book, Video Lectures, Accessories like Pick, Bag)',
#  'HRB MUSICALS GUITAR FLOOR STAND +GUITAR CAPO + ALICE STRING SET + AND GUITAR STRING WINDER',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L (6PCS)',
#  'Perlman Guitar Fretboard, Fingerboard Stickers, Decals Tool for Learner Or Beginner',
#  "D'Addario EZ920 85/15 Bronze Medium Light Acoustic Guitar String",
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Combo (Bag,strap,strings and 3 picks)',
#  'SHOPECOM String Acoustic Guitar | Adjustable Tuning Knob | Classical Guitar Toy | Musical Instrument Learning Toy for Kids',
#  'Intern INT-38C-L-NT Left Hand Acoustic Guitar Kit (Natural) with Carry bag, string set, picks and strap',
#  'Kadence Guitar Acoustica Series, Electric Acoustic Guitar, Ash Wood with Pickup and Inbuilt tuner (Ash Wood, Electro Acoustic)',
#  'Vault Traveller 3/4 Size Acoustic Guitar With Strings, Polishing Cloth, String Winder and Picks - Natural Gloss',
#  'GIVSON"CAMBRIDGE" 6-STRING ELECTRO-ACOUSTIC GUITAR WITH GUITAR BAG, WALL MOUNT, CAPO, STRING SET AND PICKS (BLACK)',
#  'Kadence Frontier Series, Semi Acoustic Guitar With Die Cast Keys (Bag,Strap,Strings And 3 Picks) (Natural)',
#  'Mustang Guitar Accessories Kit - Stand, Clip-on Tuner, Strap, Capo, 4 Assorted Picks, Holder - For Acoustic and Electric Instruments - Great Gift For Beginners and Advanced Players',
#  'Yamaha F310, 6-Strings Acoustic Guitar, Natural',
#  'JUAREZ Arpeggio 39 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Black',
#  'Kadence Guitar Acoustica Series, 41” Jumbo Size 6-strings Acoustic Guitar, Spruce body with Pick Guard A311',
#  'SG Musical Acoustic Acoustic Guitar Single 1st E String 1ST Guitar String (1 Strings)',
#  'Kadence Guitar Frontier Series, Blue Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks, Guitar stand, Capo and Bag, Super Combo (Blue, Acoustic)',
#  'JUAREZ Fiésta 41 Inch Acoustic Guitar Cutaway with Dual Action Truss Rod, 21 Frets Rosewood Fretboard & Bridge, Padded 5mm Cotton Bag, Cotton Strap, 2 Picks, Allen Key, Extra String Set, Black',
#  "Crizer 4 String Guitar Children's Musical Instrument Educational Toy Guitar Ukulele Instruments Beginner Musical Sound Toys Best Gift for Children",
#  'JUAREZ Belleza 39 Inch Acoustic Guitar Kit, Linden Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Brown Sunburst',
#  'Mustang 46 PCS Guitar Strings Changing Kit Guitar Tool Kit Including Guitar Strings Guitar Tuner Picks Capo Pins Guitar String Cutter and Winder for Beginner',
#  'Mustang Combo For Guitar Includes - Pick Holder,10 Picks, Guitar Strings Set Full Pack, Guitar Tuner, 1 Guitar Capo',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)',
#  'SG MUSICAL 10 Pcs Guitar Strings Stainless Steel Acoustic Guitar String 1st E String/ 2nd B String BYTD',
#  'Blueberry B-D38, 38" Acoustic Guitar Kit inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks',
#  "D'Addario EJ10 Acoustic Guitar Strings, Bronze, Extra Light",
#  'JUAREZ Arpeggio 39 Inch Semi-Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, 4 Band EQ, Chrome Die Cast Machine Tuners, Black',
#  "Toy House™ Classical Guitar Children's Musical Instrument Educational Toy Guitar for Beginners Kids Childs (Color May Vary) (Small)",
#  'Vault Junior 1/2 Size Acoustic Guitar for Kids With Gigbag, Strings, Polishing Cloth, String Winder and Picks',
#  'SG Musical - Acoustic Guitar Bag Acoustic Guitar Cover Water Proof Soft Material Black',
#  "Asago 4 String Children's Musical Guitar Instrument For Beginner Educational Toy Guitar Musical Sound Toys Best Gift for Children",
#  'Pluto HW39-201 39-inch Acoustic Guitar (Natural)',
#  'AARVI MART 4 String Musical Guitar for Kids Instrument Acoustic Learning Educational Small Toy for Child with Ability Random Brown Color Best Gift for Boys & Girls',
#  'Epiphone DR-100 6 Strings Right handed Acoustic Guitar Natural',
#  'SWINOZ Kids Guitar Toys for Kids 4-String Acoustic Guitar Musical Instrument Learning Toy for Kids (17 inches)- Multi Color',
#  'Martin Smith W-101-BK-PK Acoustic Guitar Super Kit with Stand (Black)',
#  'Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo and Guitar stand (Black Spruce Wood)',
#  'SOUVENIR 360 Degree Guitar Tuner | Digital Calibration Tuner with LCD Display for Guitar Easy to Use Highly Accurate Clip-on Electronic Tuner for Acoustic and Electric Guitar (3-Picks Included)',
#  'Crusader - Ziko Acoustic Guitar String (6 Strings)',
#  'AVNISH 4-String Acoustic Guitar Learning Kids Toy (Size : 23 inches)',
#  'Intern Made in India Acoustic Guitar package. 39 inches Cutaway Guitar with Truss Rod. Durable and long lasting with Carry bag, strings, picks and allen key, black, full (INT-IN39C-BK)',
#  'Kadence A311, 36" 6-strings Acoustic Guitar',
#  'SG Musical Acoustic Guitar Bag',
#  'Cort AD810BKS Standard Dreadnought Guitar, Spruce Top, Mahogany Back & Sides, Black Satin',
#  "DIKUJI ENTERPRISE 6 String Decor Guitar Children's Musical Instrument Educational Toy Guitar for Beginners Kids Childs (Color May Vary)",
#  '41"das musical acoustic venus guitar. cover, string, belt, 2plectrums.',
#  'Intern INT-38C Sunburst Acoustic Guitar kit with carry bag & picks',
#  'Portable Pocket Acoustic Guitar Practice Tool Gadget Chord Trainer 6 String 6 Fret Model for Beginner -MAYIS',
#  'Juarez ST38 Electric Guitar Kit/Set, Right Handed, Blue, With Case/Bag & Picks',
#  "Helly Fashion 4 String Guitar Children's Musical Instrument Educational Toy Guitar Ukulele Instruments Beginner Musical Sound Toys Best Gift for Children"]

# %%
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
url2=[]
for i in urls:
    url2.append(i.get_attribute('href'))
for url in url2:
    driver.get(url)
    try:
        deliveries=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']")
        Delivery.append(deliveries.text)
        rate=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        rates=driver.find_element_by_xpath("//span[@class='a-size-base a-color-secondary']")
        Rated.append(rates.text)
    except NoSuchElementException   as e:
        Ratings.append("No rating")
        Rated.append("No rating")
        Delivery.append("No rating")

# %%
url="https://www.amazon.in/s?k=guitar&page=2&qid=1619266454&ref=sr_pg_2"
driver.get(url)
urls=driver.find_elements_by_xpath("//img[@class='s-image']")
Images=[]
for i in urls:
    Images.append(i.get_attribute('src'))
for url in Images:
    driver.get(url)

# %%
Images
# Out:
# ['https://m.media-amazon.com/images/I/41LgRIBig8L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41AFnIwIXjL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51YQGqKVJZL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71h0UfZobVS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71oMqJAqrGL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61ckScMih0L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61TxfjPSR4L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81PkADH5B7L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61BKwRAAGkL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51utaAV1JTL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/715eINhw-KL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51q6fB4JXlS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71Hz2X6qnQL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51INShoKdNL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81RZKrARGfL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61dprEIsEmL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/212OTPVAxZL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41AbK5H5VZL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81hAETwUMSL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61xDcDixJPL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81ZsQLHQE4L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51JiB3xixFL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41KWFgh2poL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/415U9JvamGL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41riDogbf0S._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71C93t-NBeL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/610VRLFBMiL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81PjxI04pJL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51YpQPP5ivL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61V0IbfZTmL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51V-1P7P58L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61Q219szCmL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41Kg-nNVQZL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61TKGUzMJWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71w20O+3GPL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51TQCXH1BjL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71KKwP9fc3L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/613hYMuOfxL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41xlVHfxlIL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51pNU2+wvAL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61MXJxrDYhL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/718hDdbnFOL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61cPKBY45FL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61rCYOFoZ8L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71npZUbpVOL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/31mhYuIFA7L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71S9r6tCPSL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81+Wm0YlRxL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51Qdn3dBBTS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71udToZJEcL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/719C8cDq+rL._AC_UL320_.jpg']

# %%
print(len(Titles))
print(len(Prices))
print(len(Ratings))
print(len(Delivery))
print(len(Rated))
print(len(Images))
# Out:
# 111
# 109
# 113
# 130
# 113
# 51

# %%
import pandas as pd
Amazon=pd.DataFrame({})
Amazon['Titles']=Titles[0:50]
Amazon['Prices']=Prices[0:50]
Amazon['Ratings']=Ratings[0:50]
Amazon['Rates']=Rated[0:50]
Amazon['Delivery']=Delivery[0:50]
# 33  https://m.media-amazon.com/images/I/61TKGUzMJW...
# 34  https://m.media-amazon.com/images/I/71w20O+3GP...
# 35  https://m.media-amazon.com/images/I/51TQCXH1Bj...
# 36  https://m.media-amazon.com/images/I/71KKwP9fc3...
# 37  https://m.media-amazon.com/images/I/613hYMuOfx...
# 38  https://m.media-amazon.com/images/I/41xlVHfxlI...
# 39  https://m.media-amazon.com/images/I/51pNU2+wvA...
# 40  https://m.media-amazon.com/images/I/61MXJxrDYh...
# 41  https://m.media-amazon.com/images/I/718hDdbnFO...
# 42  https://m.media-amazon.com/images/I/61cPKBY45F...
# 43  https://m.media-amazon.com/images/I/61rCYOFoZ8...
# 44  https://m.media-amazon.com/images/I/71npZUbpVO...
# 45  https://m.media-amazon.com/images/I/31mhYuIFA7...
# 46  https://m.media-amazon.com/images/I/71S9r6tCPS...
# 47  https://m.media-amazon.com/images/I/81+Wm0YlRx...
# 48  https://m.media-amazon.com/images/I/51Qdn3dBBT...
# 49  https://m.media-amazon.com/images/I/71udToZJEc...

# %%
url="https://www.amazon.in/s?k=guitar&page=3&qid=1619266730&ref=sr_pg_3"

# %%
driver.get(url)

# %%
prices=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in prices:
    Prices.append(i.text)
titles=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
for i in titles:
    Titles.append(i.text)

# %%
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
url3=[]
for i in urls:
    url3.append(i.get_attribute('href'))
for url in url3:
    driver.get(url)
    try:
        deliveries=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']")
        Delivery.append(deliveries.text)
        rate=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        rates=driver.find_element_by_xpath("//span[@class='a-size-base a-color-secondary']")
        Rated.append(rates.text)
    except NoSuchElementException   as e:
        Ratings.append("No rating")
        Rated.append("No rating")
        Delivery.append("No rating")

# %%
url="https://www.amazon.in/s?k=guitar&page=3&qid=1619266730&ref=sr_pg_3"
driver.get(url)
urls=driver.find_elements_by_xpath("//img[@class='s-image']")
Images=[]
for i in urls:
    Images.append(i.get_attribute('src'))
for url in Images:
    driver.get(url)

# %%
print(len(Titles))
print(len(Prices))
print(len(Ratings))
print(len(Delivery))
print(len(Rated))
print(len(Images))
# Out:
# 159
# 157
# 162
# 188
# 162
# 48

# %%
import pandas as pd
Amazon=pd.DataFrame({})
Amazon['Titles']=Titles[0:48]
Amazon['Prices']=Prices[0:48]
Amazon['Ratings']=Ratings[0:48]
Amazon['Rates']=Rated[0:48]
Amazon['Delivery']=Delivery[0:48]
Amazon['Images']=Images[0:48]

# %%
Amazon
# Out:
#                                                Titles Prices       Ratings  \
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...  6,999  3.9 out of 5
# 1   Kadence Frontier Series, Natural Acoustic Guit...  5,999  3.8 out of 5
# 2   GUITAR BRO - COMBO (Black Acoustic Guitar for ...  6,499  3.7 out of 5
# 3   Laxmi Musical Electronics - Acoustic Pickup fo...    599  3.5 out of 5
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C 
images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
import pandas as pd
import selenium
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium import webdriver
driver =  webdriver.Chrome("chromedriver.exe")
driver.get("https://images.google.com/")
driver.maximize_window()

# %%
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')
search_bar.clear()
search_bar.send_keys(input("Enter your Search:"))
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')
search_button.click()
# Out:
# Enter your Search:cars,fruits,Machine learning

# %%
driver.execute_script("window.scrollBy(0,80000)" "")
driver.execute_script("window.scrollBy(0,80000)" "")
driver.execute_script("window.scrollBy(0,80000)" "")
driver.execute_script("window.scrollBy(0,80000)" "")
driver.execute_script("window.scrollBy(0,80000)" "")
driver.execute_script("window.scrollBy(0,80000)" "")
driver.execute_script("window.scrollBy(0,80000)" "")

# %%
urls=driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
Images=[]
for i in urls:
    Images.append(i.get_attribute('src'))

# %%
len(Images)
# Out:
# 73

# %%
urls=driver.find_elements_by_xpath("//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
headers=[]
for i in urls:
    headers.append(i.get_attribute('href'))

# %%
len(headers)
# Out:
# 73

# %%
google=pd.DataFrame({})
google['Headers']=headers
google['Images']=Images[0:100]

# %%
google
# Out:
#                                               Headers  \
# 0   https://in.pycon.org/cfp/2017/proposals/fruits...
# 1   https://ai.plainenglish.io/introduction-to-mac...
# 2   https://link.springer.com/chapter/10.1007/978-...
# 3   https://levelup.gitconnected.com/fruits-vegeta...
# 4   https://in.pycon.org/cfp/2017/proposals/fruits...
# ..                                                ...
# 68  https://automaticaddison.com/real-time-object-...
# 69  https://spectrum.ieee.org/robot-vehicles-make-...
# 70  https://www.c-sharpcorner.com/article/a-quick-...
# 71  https://www.quora.com/What-is-the-key-differen...
# 72  https://www.indiamart.com/proddetail/arzoo-bat...
#
#                                                Images
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 68  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 69  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 70  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 71  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 72  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [73 rows x 2 columns]

# %% [markdown]
# ### 4. Python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = "https://www.flipkart.com/"
driver.get(url)
driver.maximize_window()
search_glass = driver.find_element_by_class_name('_3704LK')
search_glass.send_keys("Vivo Mobile Phone")
button_1 = driver.find_element_by_xpath('/html/body/div[2]/div/div/button')
button_1.click()
driver.implicitly_wait(3)
click_button = driver.find_element_by_class_name("L0Z3Pu")
click_button.click()

# %%
Brand =[]
brand1 = driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand1:
    try:
        Brand.append(i.text)
    except:
        Brand.append("_")

# %%
len(Brand)
# Out:
# 24

# %%
Brand
# Out:
# ['vivo Y20G 2021 (Obsidian Black, 64 GB)',
#  'vivo Y20G 2021 (Purist Blue, 64 GB)',
#  'vivo Y12s (Glacier Blue, 32 GB)',
#  'vivo Y12s (Phantom Black, 32 GB)',
#  'vivo Y51A (Crystal Symphony, 128 GB)',
#  'vivo Y20A 2021 (Nebula Blue, 64 GB)',
#  'vivo Y20G (Purist Blue, 128 GB)',
#  'vivo Y20G (Obsidian Black, 128 GB)',
#  'vivo Y20A (Nebula Blue, 64 GB)',
#  'vivo Y72 5G (Prism Magic, 128 GB)',
#  'vivo Y1s (Olive Black, 32 GB)',
#  'vivo Y72 5G (Slate Gray, 128 GB)',
#  'vivo Y20A 2021 (Dawn White, 64 GB)',
#  'vivo Y21 (Diamond Glow, 128 GB)',
#  'vivo Y21 (Midnight Blue, 128 GB)',
#  'vivo Y20G (Obsidian Black, 64 GB)',
#  'vivo Y73 (Diamond Flare, 128 GB)',
#  'vivo Y20G (Purist Blue, 64 GB)',
#  'vivo V21e (Sunset Jazz, 128 GB)',
#  'vivo V21e (Dark Pearl, 128 GB)',
#  'vivo Y51A (Titanium Sapphire, 128 GB)',
#  'vivo Y51A (Crystal Symphony, 128 GB)',
#  'vivo Y73 (Roman Black, 128 GB)',
#  'vivo Y20 (Purist Blue, 64 GB)']

# %%
Ratings=[]
rating=driver.find_elements_by_class_name('_1lRcqv')
for i in rating:
    try:
        Ratings.append(i.text)
    except:
        Ratings.append("_")

# %%
len(Ratings)
# Out:
# 22

# %%
Ratings
# Out:
# ['4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4']

# %%
RAM=[]
ram1=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']/li[1]")
for i in ram1:
    try:
        RAM.append(i.text)
    except:
        RAM.append("_")

# %%
Display_Size=[]
display1=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']/li[2]")
for i in display1:
    try:
        Display_Size.append(i.text)
    except:
        Display_Size.append("_")

# %%
Display_Size
# Out:
# ['16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '15.8 cm (6.22 inch) HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display']

# %%
Camera=[]
camera1=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']/li[3]")
for i in camera1:
    try:
        Camera.append(i.text)
    except:
        Camera.append("_")

# %%
Camera
# Out:
# ['13MP + 2MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '48MP + 8MP + 2MP | 16MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '13MP Rear Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '48MP + 2MP | 8MP Front Camera',
#  '13MP Rear Camera | 5MP Front Camera',
#  '48MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '64MP + 2MP + 2MP | 16MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '64MP + 8MP | 32MP Front Camera',
#  '64MP + 8MP | 32MP Front Camera',
#  '48MP + 8MP + 2MP | 16MP Front Camera',
#  '48MP + 8MP + 2MP | 16MP Front Camera',
#  '64MP + 2MP + 2MP | 16MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera']

# %%
Battery=[]
battery1=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']/li[4]")
for i in battery1:
    try:
        Battery.append(i.text)
    except:
        Battery.append("_")

# %%
Battery
# Out:
# ['5000 mAh Li-ion Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Battery',
#  '4030 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Li-ion Battery',
#  '4000 mAh Battery',
#  '5000 mAh Li-ion Battery',
#  '4000 mAh Battery',
#  '4000 mAh Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Li-ion Battery',
#  '4000 mAh Battery',
#  '5000 mAh Lithium-ion Battery']

# %%
Warranty=[]
warranty1=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']/li[5]")
for i in warranty1:
    try:
        Warranty.append(i.text)
    except:
        Warranty.append("_")

# %%
Prices=[]
prices1=driver.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']")
for i in prices1:
    try:
        Prices.append(i.text)
    except:
        Prices.append("_")

# %%
Flipkart=pd.DataFrame({})
Flipkart['Brand']=Brand[0:22]
Flipkart['Ratings']=Ratings[0:22]
Flipkart['Inches']=Display_Size[0:22]
Flipkart['Camera']=Camera[0:22]
Flipkart['Price']=Prices[0:22]
Flipkart['RAM']=RAM[0:22]
Flipkart['Battery']=Battery[0:22]
Flipkart['Warranty']=Warranty[0:22]

# %%
Flipkart
# Out:
#                                      Brand Ratings  \
# 0   vivo Y20G 2021 (Obsidian Black, 64 GB)     4.4
# 1      vivo Y20G 2021 (Purist Blue, 64 GB)     4.4
# 2          vivo Y12s (Glacier Blue, 32 GB)     4.3
# 3         vivo Y12s (Phantom Black, 32 GB)     4.3
# 4     vivo Y51A (Crystal Symphony, 128 GB)     4.3
# 5      vivo Y20A 2021 (Nebula Blue, 64 GB)     4.4
# 6          vivo Y20G (Purist Blue, 128 GB)     4.3
# 7       vivo Y20G (Obsidian Black, 128 GB)     4.3
# 8           vivo Y20A (Nebula Blue, 64 GB)     4.3
# 9        vivo Y72 5G (Prism Magic, 128 GB)     4.3
# 10           vivo Y1s (Olive Black, 32 GB)     4.3
# 11        vivo Y72 5G (Slate Gray, 128 GB)     4.3
# 12      vivo Y20A 2021 (Dawn White, 64 GB)     4.4
# 13         vivo Y21 (Diamond Glow, 128 GB)     4.3
# 14        vivo Y21 (Midnight Blue, 128 GB)     4.3
# 15       vivo Y20G (Obsidian Black, 64 GB)     4.3
# 16        vivo Y73 (Diamond Flare, 128 GB)     4.3
# 17          vivo Y20G (Purist Blue, 64 GB)     4.3
# 18         vivo V21e (Sunset Jazz, 128 GB)     4.3
# 19          vivo V21e (Dark Pearl, 128 GB)     4.3
# 20   vivo Y51A (Titanium Sapphire, 128 GB)     4.3
# 21    vivo Y51A (Crystal Symphony, 128 GB)     4.4
#
#                                    Inches  \
# 0        16.54 cm (6.51 inch) HD+ Display
# 1        16.54 cm (6.51 inch) HD+ Display
# 2        16.54 cm (6.51 inch) HD+ Display
# 3        16.54 cm (6.51 inch) HD+ Display
# 4   16.71 cm (6.58 inch) Full HD+ Display
# 5        16.54 cm (6.51 inch) HD+ Display
# 6            16.54 cm (6.51 inch) Display
# 7        16.54 cm (6.51 inch) HD+ Display
# 8        16.54 cm (6.51 inch) HD+ Display
# 9   16.71 cm (6.58 inch) Full HD+ Display
# 10        15.8 cm (6.22 inch) HD+ Display
# 11  16.71 cm (6.58 inch) Full HD+ Display
# 12       16.54 cm (6.51 inch) HD+ Display
# 13       16.54 cm (6.51 inch) HD+ Display
# 14       16.54 cm (6.51 inch) HD+ Display
# 15       16.54 cm (6.51 inch) HD+ Display
# 16  16.36 cm (6.44 inch) Full HD+ Display
# 17       16.54 cm (6.51 inch) HD+ Display
# 18  16.36 cm (6.44 inch) Full HD+ Display
# 19  16.36 cm (6.44 inch) Full HD+ Display
# 20  16.71 cm (6.58 inch) Full HD+ Display
# 21  16.71 cm (6.58 inch) Full HD+ Display
#
#                                   Camera    Price  \
# 0    13MP + 2MP + 2MP | 8MP Front Camera  ₹13,990
# 1    13MP + 2MP + 2MP | 8MP Front Camera  ₹13,990
# 2          13MP + 2MP | 8MP Front Camera  ₹10,990
# 3          13MP + 2MP | 8MP Front Camera  ₹10,990
# 4   48MP + 8MP + 2MP | 16MP Front Camera  ₹17,990
# 5    13MP + 2MP + 2MP | 8MP Front Camera  ₹11,990
# 6                       13MP Rear Camera  ₹15,990
# 7    13MP + 2MP + 2MP | 8MP Front Camera  ₹15,990
# 8    13MP + 2MP + 2MP | 8MP Front Camera  ₹11,625
# 9          48MP + 2MP | 8MP Front Camera  ₹20,990
# 10   13MP Rear Camera | 5MP Front Camera   ₹9,490
# 11         48MP + 2MP | 8MP Front Camera  ₹20,990
# 12   13MP + 2MP + 2MP | 8MP Front Camera  ₹11,990
# 13         13MP + 2MP | 8MP Front Camera  ₹15,490
# 14         13MP + 2MP | 8MP Front Camera  ₹15,490
# 15   13MP + 2MP + 2MP | 8MP Front Camera  ₹13,990
# 16  64MP + 2MP + 2MP | 16MP Front Camera  ₹20,990
# 17   13MP + 2MP + 2MP | 8MP Front Camera  ₹13,990
# 18        64MP + 8MP | 32MP Front Camera  ₹24,990
# 19        64MP + 8MP | 32MP Front Camera  ₹24,990
# 20  48MP + 8MP + 2MP | 16MP Front Camera  ₹16,990
# 21  48MP + 8MP + 2MP | 16MP Front Camera  ₹16,990
#
#                                               RAM                   Battery  \
# 0   4 GB RAM | 64 GB ROM | Expandable Upto 256 GB   5000 mAh Li-ion Battery
# 1   4 GB RAM | 64 GB ROM | Expandable Upto 256 GB   5000 mAh Li-ion Battery
# 2   3 GB RAM | 32 GB ROM | Expandable Upto 256 GB   5000 mAh Li-ion Battery
# 3   3 GB RAM | 32 GB ROM | Expandable Upto 256 GB   5000 mAh Li-ion Battery
# 4    8 GB RAM | 128 GB ROM | Expandable Upto 1 TB   5000 mAh Li-ion Battery
# 5   3 GB RAM | 64 GB ROM | Expandable Upto 256 GB          5000 mAh Battery
# 6                           6 GB RAM | 128 GB ROM          5000 mAh Battery
# 7    6 GB RAM | 128 GB ROM | Expandable Upto 1 TB   5000 mAh Li-ion Battery
# 8   3 GB RAM | 64 GB ROM | Expandable Upto 256 GB   5000 mAh Li-ion Battery
# 9                           8 GB RAM | 128 GB ROM          5000 mAh Battery
# 10  3 GB RAM | 32 GB ROM | Expandable Upto 256 GB          4030 mAh Battery
# 11                          8 GB RAM | 128 GB ROM          5000 mAh Battery
# 12  3 GB RAM | 64 GB ROM | Expandable Upto 256 GB          5000 mAh Battery
# 13   4 GB RAM | 128 GB ROM | Expandable Upto 1 TB  5000 mAh Lithium Battery
# 14   4 GB RAM | 128 GB ROM | Expandable Upto 1 TB  5000 mAh Lithium Battery
# 15    4 GB RAM | 64 GB ROM | Expandable Upto 1 TB   5000 mAh Li-ion Battery
# 16                          8 GB RAM | 128 GB ROM          4000 mAh Battery
# 17    4 GB RAM | 64 GB ROM | Expandable Upto 1 TB   5000 mAh Li-ion Battery
# 18   8 GB RAM | 128 GB ROM | Expandable Upto 1 TB          4000 mAh Battery
# 19   8 GB RAM | 128 GB ROM | Expandable Upto 1 TB          4000 mAh Battery
# 20   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB   5000 mAh Li-ion Battery
# 21   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB   5000 mAh Li-ion Battery
#
#                              Warranty
# 0        MediaTek Helio P35 Processor
# 1        MediaTek Helio P35 Processor
# 2            Snapdragon 439 Processor
# 3            Snapdragon 439 Processor
# 4   Qualcomm Snapdragon 662 Processor
# 5   Qualcomm Snapdragon 439 Processor
# 6                              1 year
# 7        MediaTek Helio G80 Processor
# 8   Qualcomm Snapdragon 439 Processor
# 9   Qualcomm Snapdragon 480 Processor
# 10       MediaTek Helio P35 Processor
# 11  Qualcomm Snapdragon 480 Processor
# 12  Qualcomm Snapdragon 439 Processor
# 13       Mediatek Helio P35 Processor
# 14       Mediatek Helio P35 Processor
# 15       MediaTek Helio G80 Processor
# 16       MediaTek Helio G95 Processor
# 17       MediaTek Helio G80 Processor
# 18   MediaTek Dimensity 700 Processor
# 19   MediaTek Dimensity 700 Processor
# 20  Qualcomm Snapdragon 662 Processor
# 21  Qualcomm Snapdragon 662 Processor

# %% [markdown]
# ### 5. Python program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import pandas as pd
import selenium
import requests
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://maps.google.com/")

# %%
driver.maximize_window()
search_box = driver.find_element_by_id("searchboxinput")
search_box.send_keys(input("Enter your Search:"))
# Out:
# Enter your Search:Bagalkot

# %%
search_button = driver.find_element_by_id ("searchbox-searchbutton")
search_button.click()

# %%
address = driver.current_url

# %%
address
# Out:
# 'https://www.google.com/maps/place/Bagalkot,+Karnataka/@16.1671457,75.6237991,13z/data=!3m1!4b1!4m5!3m4!1s0x3bc77889eae13979:0x2911d2fb816d80c4!8m2!3d16.1691096!4d75.6615029'

# %%
address =address.split(sep="/")

# %%
address
# Out:
# ['https:',
#  '',
#  'www.google.com',
#  'maps',
#  'place',
#  'Bagalkot,+Karnataka',
#  '@16.1671457,75.6237991,13z',
#  'data=!3m1!4b1!4m5!3m4!1s0x3bc77889eae13979:0x2911d2fb816d80c4!8m2!3d16.1691096!4d75.6615029']

# %%
address[6]
# Out:
# '@16.1671457,75.6237991,13z'

# %% [markdown]
# ### 6. Python program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
import pandas as pd
import selenium
import requests
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver =  webdriver.Chrome("chromedriver.exe")
driver.get("https://trak.in/india-startup-funding-investment-2015/")

# %%
driver.maximize_window()
title_tags = driver.find_elements_by_xpath("//div[@class='dataTables_scroll']")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="7910ad12-729e-428f-bb5a-576f4222b5d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="fe3a36ca-4d61-4333-895a-be71c0daf753")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="8947b66e-c2e0-4dc5-aa69-c6f4c0952628")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="916f5a2a-e430-496c-a738-231e147251eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="e0653707-5e34-4c74-bb04-7c78afff3b02")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="4a8ebd4a-0a8d-4c68-982e-55357776cd63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="81b6110b-f0d6-43c9-9cc9-beca3a7ef9a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="330a9c4a-4c43-456a-ada9-32d804383d17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="55c65f00-f005-4336-b469-0f08857b98d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="5a313671-5c0f-43fa-979c-7aa477d9c787")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="b11ea8e1-0618-4cea-8346-77a31555f1d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="bd882ba5-eb4e-4370-b188-9d77031a68cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="299105b3-af21-4b73-bc28-a350af40d147")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="7ace3b63-d85e-4593-88ad-4316f775c9ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="f4c6b702-240e-45e6-89d5-98a2266128d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="b18124e2-3b0f-4121-9f2a-cace1b5a3a6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="afda1904-a7e2-49d8-a77e-9beee1a2dc0c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="0c3db7d8-6879-44af-9620-22f5e4b498b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="bac920c6-c6d9-49f3-92d8-71102fc1ca2d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="3d3c004d-a25b-4257-a031-8c9ec7214bef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="94cbfcda-d83f-4f78-abe9-ddf7b280b07a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="ea06855f-4283-44fb-93f5-a37524e6d8cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="f7377285-9cad-4ec5-85d0-825d85663f20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="9dbf068c-b711-4ad3-b88e-ae3487ac1650")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="cfb523dc-14bb-48ab-afc6-36605428b57d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="e0b7a039-1a9a-4adc-9ace-03bcce404576")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="bce9cef5-0493-446c-8d89-5a9d67d5b46e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="e7aee99f-5e59-4fa8-a450-44f17d992f2a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="55ffcd5f-6ce2-40c1-a00f-4736434c5037")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element="0df97586-2af2-4066-ae7b-9c60e2e91ea3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="345a7d57806bf1baae63de3b85fe70eb", element
services Bangalore Existing Backers In Progress 30,000,000\n5 11/08/2020 Terra.do EduTech Online Climate School, E-learning Stanford, California, Stanford Angels and Entrepreneurs (India), BEENEXT Emerging Asia, Rainmatter Capital\n\nSeed 1,400,000\n6 12/08/2020 Classplus EduTech E-learning, Online Tutoring\n\nNoida Falcon Edge In Progress upto 15,000,000\n7 14/08/2020 Niyo FinTech Financial Services Bangalore Niyo Solutions Inc. 6,000,000\n8 10/08/2020 ZestMoney FinTech Financial Services Bangalore Primrose Hills Ventures 10,670,000\n9 07/08/2020 FreshToHome E-commerce Food Delivery Bangalore Ascent Capital Venture 16,200,000\n10 13/08/2020 Eduvanz FinTech Financial Services Mumbai Sequoia India, Unitus Series A 5,000,000"]

# %% [markdown]
# ### 7.  Program to scrap all the available details of best gaming laptops from digit.in.

# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome("chromedriver.exe")
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
driver.maximize_window()
title_tags = driver.find_elements_by_xpath("//div[@class='TopNumbeHeading active sticky-footer']")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="1be82956-e3c7-4a2a-8404-e5015b2671ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="9ab078e8-7e4c-4baa-8e3c-c9dfe7292771")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="0f240528-dc3a-42a0-9577-cbc09c6e10bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="0dcce8a8-5147-4ca5-8725-4148c9adc640")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="3c8ab2a1-4550-4d67-94ca-9e8819c671c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="9bd3b8e6-3918-4770-8121-31250d0c7781")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="d7cc9e3c-d8e3-442d-a49a-9ddc38cdbb9b")>]

# %%
Titles=[]
for i in title_tags:
    title=i.text
    Titles.append(title)

# %%
Titles
# Out:
# ['1.\nALIENWARE AREA 51M R2',
#  '2.\nALIENWARE M15 R3',
#  '3.\nASUS ROG STRIX SCAR 15',
#  '4.\nASUS ROG ZEPHYRUS G14',
#  '5.\nLENOVO LEGION 5I',
#  '6.\nASUS ROG ZEPHYRUS DUO 15',
#  '7.\nACER ASPIRE 7 GAMING']

# %%
windows_tags = driver.find_elements_by_xpath("//div[@class='product-detail']")
windows_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="b3d42284-ffbd-4ea0-b81b-03198e655719")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="b242f49b-c85b-4a04-8356-6b88ad127346")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="16f30b3f-f2ad-454c-8c8d-945cf1b38f0c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="e95ef9a7-e99c-44fb-b9ea-44547ccc0051")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="4b98881b-0689-466c-a561-2cac1cd99e93")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="1e2c73e7-7974-4075-8bf2-bc5fe566e412")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="760a64b77e495fa400e9d6445215ca90", element="8e951ee0-ab3f-4f0a-b285-1c1ef83dc6df")>]

# %%
detail=[]
for i in windows_tags:
    wind=i.text
    detail.append(wind)

# %%
detail
# Out:
# ['OS\nWINDOWS 10 HOME\nDISPLAY\n17.3" (1920 X 1080)\nPROCESSOR\n10TH GENERATION INTEL® CORE™ I7-10700 | 2.90 GHZ\nMEMORY\n1 TB SSD/16 GBGB DDR4\nFULL SPECS OTHER ALIENWARE LAPTOPS',
#  'OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (3840 X 2160)\nPROCESSOR\n10TH GENERATION INTEL® CORE™ I9-10980HK | NA\nMEMORY\n1 TB SSD/16 GBGB DDR4\nFULL SPECS OTHER ALIENWARE LAPTOPS',
#  'OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (1920 X 1080)\nPROCESSOR\nAMD RYZEN™ 9 5900HX | 3.3 GHZ\nMEMORY\n1 TB SSD/16 GBGB DDR4\nREAD REVIEW FULL SPECS OTHER ASUS LAPTOPS',
#  'OS\nWINDOWS 10 HOME\nDISPLAY\n14" (1920 X 1080)\nPROCESSOR\nAMD 3RD GENERATION RYZEN 9 | 3.3 GHZ\nMEMORY\n1 TB SSD/16 GBGB DDR4\nREAD REVIEW FULL SPECS OTHER ASUS LAPTOPS',
#  'OS\nWINDOWS 10 PRO\nDISPLAY\n15.6" (1920 X 1080)\nPROCESSOR\n10TH GENERATION INTEL® CORE™ I5-10300H | 2.50 GHZ\nMEMORY\n1 TB SSD/16 GBGB DDR4\nFULL SPECS OTHER LENOVO LAPTOPS',
#  'OS\nWINDOWS 10\nDISPLAY\n15.6" (3840 X 1100)\nPROCESSOR\nINTEL CORE I7 10TH GEN 10875H | NA\nMEMORY\n512 GB SSD/4 GBGB DDR4\nFULL SPECS OTHER ASUS LAPTOPS',
#  'OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (1920 X 1080)\nPROCESSOR\nAMD RYZEN™ 5-5500U HEXA-CORE | NA\nMEMORY\n512 GB SSD/8 GBGB DDR4\nREAD REVIEW FULL SPECS OTHER ACER LAPTOPS']

# %%
urls=driver.find_elements_by_xpath("//div[@class='product-ickon']/img")
url1=[]
for i in urls:
    url1.append(i.get_attribute('src'))

# %%
url1
# Out:
# ['https://static.digit.in/product/thumb_184799_product_td_300.jpeg',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png']

# %%
import pandas as pd
Digit=pd.DataFrame({})
Digit['Titles']=Titles
Digit['Product Details']=detail
Digit['Image Links']=url1
Digit
# Out:
#                          Titles  \
# 0     1.\nALIENWARE AREA 51M R2
# 1          2.\nALIENWARE M15 R3
# 2    3.\nASUS ROG STRIX SCAR 15
# 3     4.\nASUS ROG ZEPHYRUS G14
# 4          5.\nLENOVO LEGION 5I
# 5  6.\nASUS ROG ZEPHYRUS DUO 15
# 6      7.\nACER ASPIRE 7 GAMING
#
#                                      Product Details  \
# 0  OS\nWINDOWS 10 HOME\nDISPLAY\n17.3" (1920 X 10...
# 1  OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (3840 X 21...
# 2  OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (1920 X 10...
# 3  OS\nWINDOWS 10 HOME\nDISPLAY\n14" (1920 X 1080...
# 4  OS\nWINDOWS 10 PRO\nDISPLAY\n15.6" (1920 X 108...
# 5  OS\nWINDOWS 10\nDISPLAY\n15.6" (3840 X 1100)\n...
# 6  OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (1920 X 10...
#
#                                          Image Links
# 0  https://static.digit.in/product/thumb_184799_p...
# 1  https://www.digit.in/images/digit_topten_icon.png
# 2  https://www.digit.in/images/digit_topten_icon.png
# 3  https://www.digit.in/images/digit_topten_icon.png
# 4  https://www.digit.in/images/digit_topten_icon.png
# 5  https://www.digit.in/images/digit_topten_icon.png
# 6  https://www.digit.in/images/digit_topten_icon.png

# %% [markdown]
# ### 8. Python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://www.forbes.com/real-time-billionaires/#6f1445f93d78")

# %%
Rank = driver.find_elements_by_xpath("//td[@class='rank']")
len(Rank)
# Out:
# 25

# %%
Ranks = []
for i in Rank:
    Ranks.append(i.text)

# %%
Name = driver.find_elements_by_xpath("//td[@class='name']")
len(Name)
# Out:
# 25

# %%
Names = []
for i in Name:
    Names.append(i.text)

# %%
Worth = driver.find_elements_by_xpath("//td[@class='Net Worth']")
len(Worth)
# Out:
# 25

# %%
Net_Worth = []
for i in Worth:
    Net_Worth.append(i.text)

# %%
Age = driver.find_elements_by_xpath("//td[@class='age']")
len(Age)
# Out:
# 25

# %%
Age_of_Billionaire = []
for i in Age:
    Age_of_Billionaire.append(i.text)

# %%
Source = driver.find_elements_by_xpath("//td[@class='source']")
len(Source)
# Out:
# 25

# %%
Source_of_Billionaire = []
for i in Source:
    Source_of_Billionaire.append(i.text)

# %%
Country = driver.find_elements_by_xpath("//td[@class='Country/Territory']")
len(Country)
# Out:
# 25

# %%
Country_of_Billionaire = []
for i in Country:
    Country_of_Billionaire.append(i.text)

# %%
import pandas as pd
Billionare=pd.DataFrame({})
Billionare['Rank']= Ranks
Billionare['Name']= Names
Billionare['Net Worth']= Net_Worth
Billionare['Age']= Age_of_Billionaire
Billionare['Source']= Source_of_Billionaire
Billionare['Country']= Country_of_Billionaire

# %%
Billionare.head()
# Out:
#   Rank                      Name Net Worth Age         Source        Country
# 0    1                Jeff Bezos  $188.8 B  57         Amazon  United States
# 1    2                 Elon Musk  $183.7 B  50  Tesla, SpaceX  United States
# 2    3  Bernard Arnault & family  $180.3 B  72           LVMH         France
# 3    4                Bill Gates  $131.6 B  65      Microsoft  United States
# 4    5           Mark Zuckerberg  $131.1 B  37       Facebook  United States

# %% [markdown]
# ### 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://www.youtube.com/watch?v=YfO28Ihehbk")
driver.maximize_window()
driver.execute_script("window.scrollBy(0,10000)" "")

# %%
for i in range(200):
    driver.execute_script("window.scrollBy(0,10000)" "")

# %%
Comment = driver.find_elements_by_id("content-text")
len(Comment)
# Out:
# 20

# %%
Comments = []
for i in Comment:
    Comments.append(i.text)

# %%
comment_upvote = driver.find_elements_by_id("vote-count-middle")
len(comment_upvote)
# Out:
# 20

# %%
Comment_Upvotes = []
for i in comment_upvote:
    Comment_Upvotes.append(i.text)

# %%
time1 = driver.find_elements_by_xpath("//*[@id='header-author']/yt-formatted-string/a")
len(time1)
# Out:
# 20

# %%
Time = []
for i in time1:
    Time.append(i.text)

# %%
import pandas as pd
Youtube=pd.DataFrame({})
Youtube['Comments']= Comments
Youtube['Comment Upvotes']= Comment_Upvotes
Youtube['Times']= Time

# %%
Youtube.head()
# Out:
#                                             Comments Comment Upvotes  \
# 0  01:04 introduction to python\n05:14 Python set...             478
# 1  Whenever it comes to coding, I always prefer y...              35
# 2  This course is sitting in my watch later playl...               4
# 3  I'm at the middle of this session , and one in...               7
# 4  Very interactive way of teaching. I like this....              16
#
#                    Times
# 0            2 years ago
# 1             1 year ago
# 2            3 weeks ago
# 3  3 months ago (edited)
# 4             1 year ago

# %% [markdown]
# ### 10. Python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-07-23&to=2021-07-26&guests=2&page=1")

# %%
Hostel_Name1 = driver.find_elements_by_xpath("//h2[@class='title title-6']/a")
Hostel_Name = []
for i in Hostel_Name1:
    Hostel_Name.append(i.text)

# %%
Distance = driver.find_elements_by_class_name('description')

# %%
Distance_from_City_Centre = []

# %%
for i in Distance:
    Distance_from_City_Centre.append(i.text)

# %%
rating = driver.find_elements_by_xpath("//div[@class='score orange big']")

# %%
Ratings = []
for i  in rating:
    try:
        Ratings.append(i.text)
    except NoSuchElementException as E:
        Ratings.append("__")

# %%
Total_Reviews1 = driver.find_elements_by_xpath("//div[@class='reviews']")

# %%
Total_Reviews =[]
for i in Total_Reviews1:
    Total_Reviews.append(i.text)

# %%
Overall_reviews1 = driver.find_elements_by_xpath("//div[@class='keyword']")

# %%
Overall_Reviews =[]
for i in Overall_reviews1:
    Overall_Reviews.append(i.text)

# %%
privates_from_price1 =driver.find_elements_by_xpath("//div[@class='price title-5']")
Privates_from_price =[]
for i in privates_from_price1:
    Privates_from_price.append(i.text)

# %%
Privates_from_price = Privates_from_price[0::2]

# %%
dorms_from_price1 = driver.find_elements_by_xpath("//div[@class='price title-5']")
Dorms_from_price =[]
for i in dorms_from_price1:
    Dorms_from_price.append(i.text)

# %%
Dorms_from_price = Dorms_from_price[1::2]

# %%
facilities1 = driver.find_elements_by_xpath("//div[@class='facilities-label facilities']")
Facilities=[]
for i in facilities1:
    Facilities.append(i.text)

# %%
property_description1 = driver.find_elements_by_xpath("//div[@class='rating-factors prop-card-tablet rating-factors small']")
Property_Description =[]
for i in property_description1:
    Property_Description.append(i.text)

# %%
import pandas as pd
Hostel=pd.DataFrame({})
Hostel['Hostel Name']= Hostel_Name[0:20]
Hostel['Distance from City Centre']= Distance_from_City_Centre[0:20]
Hostel['Ratings']= Ratings[0:20]
Hostel['Total Reviews']= Total_Reviews[0:20]
Hostel['Overall Reviews']= Overall_Reviews[0:20]
Hostel['Privates from Price']= Privates_from_price[0:20]
Hostel['Dorms from Prices']= Dorms_from_price[0:20]
Hostel['Property Description']= Property_Description[0:20]
Hostel['Facilities']= Facilities[0:20]

# %%
Hostel.head(10)
# Out:
#                             Hostel Name        Distance from City Centre  \
# 0                London Waterloo Hostel  Hostel - 0.7km from city centre
# 1              Barmy Badger Backpackers  Hostel - 5.5km from city centre
# 2       Wombat's The City Hostel London  Hostel - 3.6km from city centre
# 3               Prime Backpackers Angel  Hostel - 3.6km from city centre
# 4              St Christopher's Village  Hostel - 1.8km from city centre
# 5  PubLove @ The Steam Engine, Waterloo  Hostel - 0.5km from city centre
# 6        PubLove @ The Crown, Battersea  Hostel - 4.7km from city centre
# 7     Safestay London Elephant & Castle  Hostel - 1.7km from city centre
# 8                  Urbany Hostel London  Hostel - 5.4km from city centre
# 9   PubLove @ The Green Man, Paddington  Hostel - 4.3km from city centre
#
#   Ratings        Total Reviews Overall Reviews Privates from Price  \
# 0     7.5   2409 Total Reviews          Superb              Rs1414
# 1      10   1653 Total Reviews          Superb              Rs8170
# 2     9.2  13143 Total Reviews        Fabulous              Rs6041
# 3      10    513 Total Reviews       Very Good              Rs3446
# 4     8.9  10830 Total Reviews          Superb              Rs1520
# 5     9.0    190 Total Reviews          Superb              Rs1520
# 6     6.7    208 Total Reviews          Superb              Rs1824
# 7     8.1   3952 Total Reviews        Fabulous              Rs1824
# 8      10    106 Total Reviews          Superb              Rs1520
# 9      10    392 Total Reviews            Good              Rs1520
#
#   Dorms from Prices                               Property Description  \
# 0            Rs2129  Perfect Location\nSuperb Staff\nAwesome Cleanl...
# 1            Rs1856  Perfect Location\nSuperb Staff\nFantastic Clea...
# 2            Rs2398  Perfect Location\nSuperb Staff\nFantastic Clea...
# 3            Rs1358  Perfect Location\nSuperb Staff\nFantastic Clea...
# 4            Rs8612  Perfect Location\nSuperb Staff\nFantastic Clea...
# 5            Rs5473  Perfect Location\nSuperb Staff\nFantastic Clea...
# 6            Rs4332               Wonderful Location\nMarvellous Staff
# 7            Rs6082  Perfect Location\nMarvellous Staff\nExcellent ...
# 8            Rs3178  Perfect Location\nSuperb Staff\nFantastic Clea...
# 9            Rs3120                                   Good Cleanliness
#
#                                           Facilities
# 0  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...
# 1                          Free WiFi\nFree Breakfast
# 2    Free WiFi\nFollows Covid-19 sanitation guidance
# 3    Free WiFi\nFollows Covid-19 sanitation guidance
# 4    Free WiFi\nFollows Covid-19 sanitation guidance
# 5    Free WiFi\nFollows Covid-19 sanitation guidance
# 6    Free WiFi\nFollows Covid-19 sanitation guidance
# 7    Free WiFi\nFollows Covid-19 sanitation guidance
# 8    Free WiFi\nFollows Covid-19 sanitation guidance
# 9    Free WiFi\nFollows Covid-19 sanitation guidance
